# %% [markdown]
# # Face Generation
#
# In this project, you'll define and train a DCGAN on a dataset of faces. Your goal is to get a generator network to generate *new* images of faces that look as realistic as possible!
#
# The project will be broken down into a series of tasks from **loading in data to defining and training adversarial networks**. At the end of the notebook, you'll be able to visualize the results of your trained Generator to see how it performs; your generated samples should look like fairly realistic faces with small amounts of noise.
#
# ### Get the Data
#
# You'll be using the [CelebFaces Attributes Dataset (CelebA)](http://mmlab.ie.cuhk.edu.hk/projects/CelebA.html) to train your adversarial networks.
#
# This dataset is more complex than the number datasets (like MNIST or SVHN) you've been working with, and so, you should prepare to define deeper networks and train them for a longer time to get good results. It is suggested that you utilize a GPU for training.
#
# ### Pre-processed Data
#
# Since the project's main focus is on building the GANs, we've done *some* of the pre-processing for you. Each of the CelebA images has been cropped to remove parts of the image that don't include a face, then resized down to 64x64x3 NumPy images. Some sample data is show below.
#
# <img src='assets/processed_face_data.png' width=60% />
#
# > If you are working locally, you can download this data [by clicking here](https://s3.amazonaws.com/video.udacity-data.com/topher/2018/November/5be7eb6f_processed-celeba-small/processed-celeba-small.zip)
#
# This is a zip file that you'll need to extract in the home directory of this notebook for further loading and processing. After extracting the data, you should be left with a directory of data `processed_celeba_small/`

# %%
# can comment out after executing
# !unzip processed_celeba_small.zip
# Out:
# 'unzip' is not recognized as an internal or external command,
# operable program or batch file.

# %%
data_dir = 'processed_celeba_small/'

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle as pkl
import matplotlib.pyplot as plt
import numpy as np
import problem_unittests as tests
#import helper

# %matplotlib inline

# %% [markdown]
# ## Visualize the CelebA Data
#
# The [CelebA](http://mmlab.ie.cuhk.edu.hk/projects/CelebA.html) dataset contains over 200,000 celebrity images with annotations. Since you're going to be generating faces, you won't need the annotations, you'll only need the images. Note that these are color images with [3 color channels (RGB)](https://en.wikipedia.org/wiki/Channel_(digital_image)#RGB_Images) each.
#
# ### Pre-process and Load the Data
#
# Since the project's main focus is on building the GANs, we've done *some* of the pre-processing for you. Each of the CelebA images has been cropped to remove parts of the image that don't include a face, then resized down to 64x64x3 NumPy images. This *pre-processed* dataset is a smaller subset of the very large CelebA data.
#
# > There are a few other steps that you'll need to **transform** this data and create a **DataLoader**.
#
# #### Exercise: Complete the following `get_dataloader` function, such that it satisfies these requirements:
#
# * Your images should be square, Tensor images of size `image_size x image_size` in the x and y dimension.
# * Your function should return a DataLoader that shuffles and batches these Tensor images.
#
# #### ImageFolder
#
# To create a dataset given a directory of images, it's recommended that you use PyTorch's [ImageFolder](https://pytorch.org/docs/stable/torchvision/datasets.html#imagefolder) wrapper, with a root directory `processed_celeba_small/` and data transformation passed in.

# %%
# necessary imports
import torch
from torchvision import datasets
from torchvision import transforms

# %%
def get_dataloader(batch_size, image_size, data_dir='processed_celeba_small/'):
    """
    Batch the neural network data using DataLoader
    :param batch_size: The size of each batch; the number of images in a batch
    :param img_size: The square size of the image data (x, y)
    :param data_dir: Directory where image data is located
    :return: DataLoader with batched data
    """
    
    # TODO: Implement function and return a dataloader
    transform = transforms.Compose([transforms.Resize(image_size), # resize to 128x128
                                    transforms.ToTensor()])
    
    img_dataset = datasets.ImageFolder(data_dir, transform)
    
    img_loader = torch.utils.data.DataLoader(dataset=img_dataset, batch_size=batch_size, shuffle=True)
    
    return img_loader

# %% [markdown]
# ## Create a DataLoader
#
# #### Exercise: Create a DataLoader `celeba_train_loader` with appropriate hyperparameters.
#
# Call the above function and create a dataloader to view images.
# * You can decide on any reasonable `batch_size` parameter
# * Your `image_size` **must be** `32`. Resizing the data to a smaller size will make for faster training, while still creating convincing images of faces!

# %%
# Define function hyperparameters
batch_size = 20
img_size = 32

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# Call your function and get a dataloader
celeba_train_loader = get_dataloader(batch_size, img_size)

# %% [markdown]
# Next, you can view some images! You should seen square images of somewhat-centered faces.
#
# Note: You'll need to convert the Tensor images into a NumPy type and transpose the dimensions to correctly display an image, suggested `imshow` code is below, but it may not be perfect.

# %%
# helper display function
def imshow(img):
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# obtain one batch of training images
dataiter = iter(celeba_train_loader)
images, _ = dataiter.next() # _ for no labels

# plot the images in the batch, along with the corresponding labels
fig = plt.figure(figsize=(20, 4))
plot_size=20
for idx in np.arange(plot_size):
    ax = fig.add_subplot(2, plot_size/2, idx+1, xticks=[], yticks=[])
    imshow(images[idx])

# %% [markdown]
# #### Exercise: Pre-process your image data and scale it to a pixel range of -1 to 1
#
# You need to do a bit of pre-processing; you know that the output of a `tanh` activated generator will contain pixel values in a range from -1 to 1, and so, we need to rescale our training images to a range of -1 to 1. (Right now, they are in a range from 0-1.)

# %%
# TODO: Complete the scale function
def scale(x, feature_range=(-1, 1)):
    ''' Scale takes in an image x and returns that image, scaled
       with a feature_range of pixel values from -1 to 1. 
       This function assumes that the input x is already scaled from 0-1.'''
    # assume x is scaled to (0, 1)
    # scale to feature_range and return scaled x
    x = x*(feature_range[1] - feature_range[0]) + feature_range[0]
    
    return x

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# check scaled range
# should be close to -1 to 1
img = images[0]
scaled_img = scale(img)

print('Min: ', scaled_img.min())
print('Max: ', scaled_img.max())
# Out:
# Min:  tensor(-0.6706)
# Max:  tensor(0.9922)

# %% [markdown]
# ---
# # Define the Model
#
# A GAN is comprised of two adversarial networks, a discriminator and a generator.
#
# ## Discriminator
#
# Your first task will be to define the discriminator. This is a convolutional classifier like you've built before, only without any maxpooling layers. To deal with this complex data, it's suggested you use a deep network with **normalization**. You are also allowed to create any helper functions that may be useful.
#
# #### Exercise: Complete the Discriminator class
# * The inputs to the discriminator are 32x32x3 tensor images
# * The output should be a single value that will indicate whether a given image is real or fake

# %%
import torch.nn as nn
import torch.nn.functional as F

#helper functions
def conv(in_channel, out_channel, kernel_size, stride=2, padding=1, batch_norm=True):
    layers = []
    conv_layer = nn.Conv2d(in_channel, out_channel,
                           kernel_size, stride, padding, bias = False)
    
    layers.append(conv_layer)
    
    if batch_norm:
        layers.append(nn.BatchNorm2d(out_channel))
        
    return nn.Sequential(*layers)

def deconv(in_channel, out_channel, kernel_size, stride=2, padding=1, batch_norm=True):
    layers = []
    conv_t_layer = nn.ConvTranspose2d(in_channel, out_channel,
                           kernel_size, stride, padding, bias = False)
    
    layers.append(conv_t_layer)
    
    if batch_norm:
        layers.append(nn.BatchNorm2d(out_channel))
        
    return nn.Sequential(*layers)

# %%
class Discriminator(nn.Module):

    def __init__(self, conv_dim):
        """
        Initialize the Discriminator Module
        :param conv_dim: The depth of the first convolutional layer
        """
        super(Discriminator, self).__init__()

        # complete init function
        self.conv_dim = conv_dim
        #32 x 32
        self.conv1 = conv(3, conv_dim, 4, batch_norm=False)
        #16 x 16
        self.conv2 = conv(conv_dim, conv_dim*2, 4)
        #8 x 8
        self.conv3 = conv(conv_dim*2, conv_dim*4, 4)
        #4 x 4
        self.fc = nn.Linear(conv_dim*4*4*4, 1)
        self.dropout = nn.Dropout(0.2)

    def forward(self, x):
        """
        Forward propagation of the neural network
        :param x: The input to the neural network     
        :return: Discriminator logits; the output of the neural network
        """
        # define feedforward behavior
        x = F.leaky_relu(self.conv1(x), 0.2)
        x = F.leaky_relu(self.conv2(x), 0.2)
        x = F.leaky_relu(self.conv3(x), 0.2)
        
        x = x.view(-1, self.conv_dim*4*4*4)
        x = self.fc(x)
        x = self.dropout(x)
        
        return x


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_discriminator(Discriminator)
# Out:
# Tests Passed

# %% [markdown]
# ## Generator
#
# The generator should upsample an input and generate a *new* image of the same size as our training data `32x32x3`. This should be mostly transpose convolutional layers with normalization applied to the outputs.
#
# #### Exercise: Complete the Generator class
# * The inputs to the generator are vectors of some length `z_size`
# * The output should be a image of shape `32x32x3`

# %%
class Generator(nn.Module):
    
    def __init__(self, z_size, conv_dim):
        """
        Initialize the Generator Module
        :param z_size: The length of the input latent vector, z
        :param conv_dim: The depth of the inputs to the *last* transpose convolutional layer
        """
        super(Generator, self).__init__()

        # complete init function
        self.conv_dim = conv_dim
        
        self.fc = nn.Linear(z_size, conv_dim*4*4*4)
        
        #4 x 4 input
        self.deconv1 = deconv(conv_dim*4, conv_dim*2, 4)
        #8 x 8
        self.deconv2 = deconv(conv_dim*2, conv_dim, 4)
        #16 x 16
        self.deconv3 = deconv(conv_dim, 3, 4, batch_norm=False)
        #32 x 32 output

    def forward(self, x):
        """
        Forward propagation of the neural network
        :param x: The input to the neural network     
        :return: A 32x32x3 Tensor image as output
        """
        # define feedforward behavior
        x = self.fc(x)
        x = x.view(-1, self.conv_dim*4, 4, 4)
        
        x = F.relu(self.deconv1(x))
        x = F.relu(self.deconv2(x))
        # nn.functional.tanh is deprecated. so, we should use torch.tanh
        x = torch.tanh(self.deconv3(x))
        
        return x

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_generator(Generator)
# Out:
# Tests Passed

# %% [markdown]
# ## Initialize the weights of your networks
#
# To help your models converge, you should initialize the weights of the convolutional and linear layers in your model. From reading the [original DCGAN paper](https://arxiv.org/pdf/1511.06434.pdf), they say:
# > All weights were initialized from a zero-centered Normal distribution with standard deviation 0.02.
#
# So, your next task will be to define a weight initialization function that does just this!
#
# You can refer back to the lesson on weight initialization or even consult existing model code, such as that from [the `networks.py` file in CycleGAN Github repository](https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix/blob/master/models/networks.py) to help you complete this function.
#
# #### Exercise: Complete the weight initialization function
#
# * This should initialize only **convolutional** and **linear** layers
# * Initialize the weights to a normal distribution, centered around 0, with a standard deviation of 0.02.
# * The bias terms, if they exist, may be left alone or set to 0.

# %%
def weights_init_normal(m):
    """
    Applies initial weights to certain layers in a model .
    The weights are taken from a normal distribution 
    with mean = 0, std dev = 0.02.
    :param m: A module or layer in a network    
    """
    # classname will be something like:
    # `Conv`, `BatchNorm2d`, `Linear`, etc.
    classname = m.__class__.__name__
    
    # TODO: Apply initial weights to convolutional and linear layers
    if hasattr(m, 'weight') and (classname.find('Linear') != -1 or classname.find('Conv') != -1):
        nn.init.normal_(m.weight.data, 0, 0.02)
        if m.bias is not None:
            nn.init.constant_(m.bias.data, 0.0)
    elif classname.find('BatchNorm2d') != -1:
        nn.init.normal_(m.weight.data, 1.0, 0.02)
        nn.init.constant_(m.bias.data, 0.0)

# %% [markdown]
# ## Build complete network
#
# Define your models' hyperparameters and instantiate the discriminator and generator from the classes defined above. Make sure you've passed in the correct input arguments.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
def build_network(d_conv_dim, g_conv_dim, z_size):
    # define discriminator and generator
    D = Discriminator(d_conv_dim)
    G = Generator(z_size=z_size, conv_dim=g_conv_dim)

    # initialize model weights
    D.apply(weights_init_normal)
    G.apply(weights_init_normal)

    print(D)
    print()
    print(G)
    
    return D, G

# %% [markdown]
# #### Exercise: Define model hyperparameters

# %%
# Define model hyperparams
d_conv_dim = 128 
g_conv_dim = 128
z_size = 100

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
D, G = build_network(d_conv_dim, g_conv_dim, z_size)
# Out:
# Discriminator(
#   (conv1): Sequential(
#     (0): Conv2d(3, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   )
#   (conv2): Sequential(
#     (0): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv3): Sequential(
#     (0): Conv2d(256, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (fc): Linear(in_features=8192, out_features=1, bias=True)
#   (dropout): Dropout(p=0.2, inplace=False)
# )
#
# Generator(
#   (fc): Linear(in_features=100, out_features=8192, bias=True)
#   (deconv1): Sequential(
#     (0): ConvTranspose2d(512, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (deconv2): Sequential(
#     (0): ConvTranspose2d(256, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (deconv3): Sequential(
#     (0): ConvTranspose2d(128, 3, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   )
# )

# %% [markdown]
# ### Training on GPU
#
# Check if you can train on GPU. Here, we'll set this as a boolean variable `train_on_gpu`. Later, you'll be responsible for making sure that
# >* Models,
# * Model inputs, and
# * Loss function arguments
#
# Are moved to GPU, where appropriate.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import torch

# Check for a GPU
train_on_gpu = torch.cuda.is_available()
if not train_on_gpu:
    print('No GPU found. Please use a GPU to train your neural network.')
else:
    print('Training on GPU!')
# Out:
# Training on GPU!

# %% [markdown]
# ---
# ## Discriminator and Generator Losses
#
# Now we need to calculate the losses for both types of adversarial networks.
#
# ### Discriminator Losses
#
# > * For the discriminator, the total loss is the sum of the losses for real and fake images, `d_loss = d_real_loss + d_fake_loss`.
# * Remember that we want the discriminator to output 1 for real images and 0 for fake images, so we need to set up the losses to reflect that.
#
#
# ### Generator Loss
#
# The generator loss will look similar only with flipped labels. The generator's goal is to get the discriminator to *think* its generated images are *real*.
#
# #### Exercise: Complete real and fake loss functions
#
# **You may choose to use either cross entropy or a least squares error loss to complete the following `real_loss` and `fake_loss` functions.**

# %%
def real_loss(D_out):
    '''Calculates how close discriminator outputs are to being real.
       param, D_out: discriminator logits
       return: real loss'''
    loss = torch.mean((D_out-1)**2)
    return loss

def fake_loss(D_out):
    '''Calculates how close discriminator outputs are to being fake.
       param, D_out: discriminator logits
       return: fake loss'''
    loss = torch.mean(D_out**2)
    return loss

# %% [markdown]
# ## Optimizers
#
# #### Exercise: Define optimizers for your Discriminator (D) and Generator (G)
#
# Define optimizers for your models with appropriate hyperparameters.

# %%
import torch.optim as optim

lr = 0.0002
beta1 = 0.5
beta2 = 0.999

# Create optimizers for the discriminator D and generator G
d_optimizer = optim.Adam(D.parameters(), lr, [beta1, beta2])
g_optimizer = optim.Adam(G.parameters(), lr, [beta1, beta2])

# %% [markdown]
# ---
# ## Training
#
# Training will involve alternating between training the discriminator and the generator. You'll use your functions `real_loss` and `fake_loss` to help you calculate the discriminator losses.
#
# * You should train the discriminator by alternating on real and fake images
# * Then the generator, which tries to trick the discriminator and should have an opposing loss function
#
#
# #### Saving Samples
#
# You've been given some code to print out some loss statistics and save some generated "fake" samples.

# %% [markdown]
# #### Exercise: Complete the training function
#
# Keep in mind that, if you've moved your models to GPU, you'll also have to move any model inputs to GPU.

# %%
def train(D, G, n_epochs, print_every=50):
    '''Trains adversarial networks for some number of epochs
       param, D: the discriminator network
       param, G: the generator network
       param, n_epochs: number of epochs to train for
       param, print_every: when to print and record the models' losses
       return: D and G losses'''
    
    # move models to GPU
    if train_on_gpu:
        D.cuda()
        G.cuda()

    # keep track of loss and generated, "fake" samples
    samples = []
    losses = []

    # Get some fixed data for sampling. These are images that are held
    # constant throughout training, and allow us to inspect the model's performance
    sample_size=16
    fixed_z = np.random.uniform(-1, 1, size=(sample_size, z_size))
    fixed_z = torch.from_numpy(fixed_z).float()
    # move z to GPU if available
    if train_on_gpu:
        fixed_z = fixed_z.cuda()

    # epoch training loop
    for epoch in range(n_epochs):

        # batch training loop
        for batch_i, (real_images, _) in enumerate(celeba_train_loader):

            batch_size = real_images.size(0)
            real_images = scale(real_images)

            # ===============================================
            #         YOUR CODE HERE: TRAIN THE NETWORKS
            # ===============================================
                            
            # ============================================
            #            TRAINING THE DISCRIMINATOR
            # ============================================
            
            d_optimizer.zero_grad()
            
            if train_on_gpu:
                real_images = real_images.cuda()
            
            # 1. Train the discriminator on real and fake images
            D_real = D(real_images)
            d_real_loss = real_loss(D_real)
            
            d_fake_image = np.random.uniform(-1, 1, size=(batch_size, z_size))
            d_fake_image = torch.from_numpy(d_fake_image).float()
            
            if train_on_gpu:
                d_fake_image = d_fake_image.cuda()
            
            fake_images = G(d_fake_image)
            
            D_fake = D(fake_images)
            d_fake_loss = fake_loss(D_fake)
            
            d_loss = d_real_loss + d_fake_loss
            d_loss.backward()
            d_optimizer.step()
            
            # =========================================
            #            TRAINING THE GENERATOR
            # =========================================
            
            g_optimizer.zero_grad()
            
            # 2. Train the generator with an adversarial loss
            g_fake_image = np.random.uniform(-1, 1, size=(batch_size, z_size))
            g_fake_image = torch.from_numpy(g_fake_image).float()
            
            if train_on_gpu:
                g_fake_image = g_fake_image.cuda()
            
            fake_images = G(g_fake_image)
            
            D_fake = D(fake_images)       
            g_loss = real_loss(D_fake)
            
            g_loss.backward()
            g_optimizer.step()            
            
            # ===============================================
            #              END OF YOUR CODE
            # ===============================================

            # Print some loss stats
            if batch_i % print_every == 0:
                # append discriminator loss and generator loss
                losses.append((d_loss.item(), g_loss.item()))
                # print discriminator and generator loss
                print('Epoch [{:5d}/{:5d}] | d_loss: {:6.4f} | g_loss: {:6.4f}'.format(
                        epoch+1, n_epochs, d_loss.item(), g_loss.item()))


        ## AFTER EACH EPOCH##    
        # this code assumes your generator is named G, feel free to change the name
        # generate and save sample, fake images
        G.eval() # for generating samples
        samples_z = G(fixed_z)
        samples.append(samples_z)
        G.train() # back to training mode

    # Save training generator samples
    with open('train_samples.pkl', 'wb') as f:
        pkl.dump(samples, f)
    
    # finally return losses
    return losses

# %% [markdown]
# Set your number of training epochs and train your GAN!

# %%
# set number of epochs 
n_epochs = 5


"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# call training function
losses = train(D, G, n_epochs=n_epochs)
# Out:
# Epoch [    1/    5] | d_loss: 6.0991 | g_loss: 6.5186
# Epoch [    1/    5] | d_loss: 2.0452 | g_loss: 2.5213
# Epoch [    1/    5] | d_loss: 3.5072 | g_loss: 1.9712
# Epoch [    1/    5] | d_loss: 2.4327 | g_loss: 6.7791
# Epoch [    1/    5] | d_loss: 1.0917 | g_loss: 3.8120
# Epoch [    1/    5] | d_loss: 0.5376 | g_loss: 1.1447
# Epoch [    1/    5] | d_loss: 0.4161 | g_loss: 1.1006
# Epoch [    1/    5] | d_loss: 0.6140 | g_loss: 1.1746
# Epoch [    1/    5] | d_loss: 0.6539 | g_loss: 1.2143
# Epoch [    1/    5] | d_loss: 0.4554 | g_loss: 0.8393
# Epoch [    1/    5] | d_loss: 0.4234 | g_loss: 1.0818
# Epoch [    1/    5] | d_loss: 0.6534 | g_loss: 0.5234
# Epoch [    1/    5] | d_loss: 0.8342 | g_loss: 0.9819
# Epoch [    1/    5] | d_loss: 0.4966 | g_loss: 0.8289
# Epoch [    1/    5] | d_loss: 0.4464 | g_loss: 0.6674
# Epoch [    1/    5] | d_loss: 0.4749 | g_loss: 0.4987
# Epoch [    1/    5] | d_loss: 0.4457 | g_loss: 0.9371
# Epoch [    1/    5] | d_loss: 0.2659 | g_loss: 1.5216
# Epoch [    1/    5] | d_loss: 0.6767 | g_loss: 0.3812
# Epoch [    1/    5] | d_loss: 0.5329 | g_loss: 0.8193
# Epoch [    1/    5] | d_loss: 0.4758 | g_loss: 1.5618
# Epoch [    1/    5] | d_loss: 0.8281 | g_loss: 0.8616
# Epoch [    1/    5] | d_loss: 0.9671 | g_loss: 0.5587
# Epoch [    1/    5] | d_loss: 0.4252 | g_loss: 0.7146
# Epoch [    1/    5] | d_loss: 0.4432 | g_loss: 0.7129
# Epoch [    1/    5] | d_loss: 0.5989 | g_loss: 0.5158
# Epoch [    1/    5] | d_loss: 0.5120 | g_loss: 0.5021
# Epoch [    1/    5] | d_loss: 0.8608 | g_loss: 0.7366
# Epoch [    1/    5] | d_loss: 0.6328 | g_loss: 0.5111
# Epoch [    1/    5] | d_loss: 0.3566 | g_loss: 1.0310
# Epoch [    1/    5] | d_loss: 0.5465 | g_loss: 0.5782
# Epoch [    1/    5] | d_loss: 0.2047 | g_loss: 0.4138
# Epoch [    1/    5] | d_loss: 0.5750 | g_loss: 0.5475
# Epoch [    1/    5] | d_loss: 0.3834 | g_loss: 0.7780
# Epoch [    1/    5] | d_loss: 0.5109 | g_loss: 0.6058
# Epoch [    1/    5] | d_loss: 0.8596 | g_loss: 1.1450
# Epoch [    1/    5] | d_loss: 0.7413 | g_loss: 0.8412
# Epoch [    1/    5] | d_loss: 0.3876 | g_loss: 0.2571
# Epoch [    1/    5] | d_loss: 0.5715 | g_loss: 1.3840
# Epoch [    1/    5] | d_loss: 0.3275 | g_loss: 0.6387
# Epoch [    1/    5] | d_loss: 0.6270 | g_loss: 0.7298
# Epoch [    1/    5] | d_loss: 0.6995 | g_loss: 0.2035
# Epoch [    1/    5] | d_loss: 0.3326 | g_loss: 0.7250
# Epoch [    1/    5] | d_loss: 0.4524 | g_loss: 0.6302
# Epoch [    1/    5] | d_loss: 0.5104 | g_loss: 0.6560
# Epoch [    1/    5] | d_loss: 0.5613 | g_loss: 0.9924
# Epoch [    1/    5] | d_loss: 0.4231 | g_loss: 0.5139
# Epoch [    1/    5] | d_loss: 0.6286 | g_loss: 0.4588
# Epoch [    1/    5] | d_loss: 0.5345 | g_loss: 0.3786
# Epoch [    1/    5] | d_loss: 0.6110 | g_loss: 0.4471
# Epoch [    1/    5] | d_loss: 1.3817 | g_loss: 1.8874
# Epoch [    1/    5] | d_loss: 0.5071 | g_loss: 0.2637
# Epoch [    1/    5] | d_loss: 0.8239 | g_loss: 0.7142
# Epoch [    1/    5] | d_loss: 0.6221 | g_loss: 0.9154
# Epoch [    1/    5] | d_loss: 0.4596 | g_loss: 0.2376
# Epoch [    1/    5] | d_loss: 0.5997 | g_loss: 1.1592
# Epoch [    1/    5] | d_loss: 0.6328 | g_loss: 1.1443
# Epoch [    1/    5] | d_loss: 0.8083 | g_loss: 1.1596
# Epoch [    1/    5] | d_loss: 0.6552 | g_loss: 0.5426
# Epoch [    1/    5] | d_loss: 0.7737 | g_loss: 0.4174
# Epoch [    1/    5] | d_loss: 0.5020 | g_loss: 0.3834
# Epoch [    1/    5] | d_loss: 0.7107 | g_loss: 0.4494
# Epoch [    1/    5] | d_loss: 0.5599 | g_loss: 0.6458
# Epoch [    1/    5] | d_loss: 0.4730 | g_loss: 0.7301
# Epoch [    1/    5] | d_loss: 0.5546 | g_loss: 0.6072
# Epoch [    1/    5] | d_loss: 0.7088 | g_loss: 0.4741
# Epoch [    1/    5] | d_loss: 0.7532 | g_loss: 0.8194
# Epoch [    1/    5] | d_loss: 0.6743 | g_loss: 0.4632
# Epoch [    1/    5] | d_loss: 0.7398 | g_loss: 0.4641
# Epoch [    1/    5] | d_loss: 0.6806 | g_loss: 1.0990
# Epoch [    1/    5] | d_loss: 0.7757 | g_loss: 0.4363
# Epoch [    1/    5] | d_loss: 0.6613 | g_loss: 0.8074
# Epoch [    1/    5] | d_loss: 0.6138 | g_loss: 0.4037
# Epoch [    1/    5] | d_loss: 0.6007 | g_loss: 0.8185
# Epoch [    1/    5] | d_loss: 0.7318 | g_loss: 0.6437
# Epoch [    1/    5] | d_loss: 0.6796 | g_loss: 0.4788
# Epoch [    1/    5] | d_loss: 0.5566 | g_loss: 0.3764
# Epoch [    1/    5] | d_loss: 0.5495 | g_loss: 0.7461
# Epoch [    1/    5] | d_loss: 0.6005 | g_loss: 0.7448
# Epoch [    1/    5] | d_loss: 0.6507 | g_loss: 0.6114
# Epoch [    1/    5] | d_loss: 0.6799 | g_loss: 0.6238
# Epoch [    1/    5] | d_loss: 0.6085 | g_loss: 0.3483
# Epoch [    1/    5] | d_loss: 0.5053 | g_loss: 0.4586
# Epoch [    1/    5] | d_loss: 0.8177 | g_loss: 0.9444
# Epoch [    1/    5] | d_loss: 0.7418 | g_loss: 0.7046
# Epoch [    1/    5] | d_loss: 0.6220 | g_loss: 0.5228
# Epoch [    1/    5] | d_loss: 0.6137 | g_loss: 0.5172
# Epoch [    1/    5] | d_loss: 0.7557 | g_loss: 0.3627
# Epoch [    1/    5] | d_loss: 0.6590 | g_loss: 0.4020
# Epoch [    1/    5] | d_loss: 0.5455 | g_loss: 0.4360
# Epoch [    2/    5] | d_loss: 0.6379 | g_loss: 0.6857
# Epoch [    2/    5] | d_loss: 0.4051 | g_loss: 0.4901
# Epoch [    2/    5] | d_loss: 0.6915 | g_loss: 0.5884
# Epoch [    2/    5] | d_loss: 0.6612 | g_loss: 0.4463
# Epoch [    2/    5] | d_loss: 0.5694 | g_loss: 0.4308
# Epoch [    2/    5] | d_loss: 0.5562 | g_loss: 0.5971
# Epoch [    2/    5] | d_loss: 0.6695 | g_loss: 1.0824
# Epoch [    2/    5] | d_loss: 0.5719 | g_loss: 0.6423
# Epoch [    2/    5] | d_loss: 0.5814 | g_loss: 0.8218
# Epoch [    2/    5] | d_loss: 0.4849 | g_loss: 0.8297
# Epoch [    2/    5] | d_loss: 0.8245 | g_loss: 0.3111
# Epoch [    2/    5] | d_loss: 0.4647 | g_loss: 0.4374
# Epoch [    2/    5] | d_loss: 0.6419 | g_loss: 0.5451
# Epoch [    2/    5] | d_loss: 1.1301 | g_loss: 0.5999
# Epoch [    2/    5] | d_loss: 0.4471 | g_loss: 0.4526
# Epoch [    2/    5] | d_loss: 0.6474 | g_loss: 0.4427
# Epoch [    2/    5] | d_loss: 0.5771 | g_loss: 0.7866
# Epoch [    2/    5] | d_loss: 0.6942 | g_loss: 0.6493
# Epoch [    2/    5] | d_loss: 0.4437 | g_loss: 0.6675
# Epoch [    2/    5] | d_loss: 0.6321 | g_loss: 0.5794
# Epoch [    2/    5] | d_loss: 0.6261 | g_loss: 0.6237
# Epoch [    2/    5] | d_loss: 0.5297 | g_loss: 0.5103
# Epoch [    2/    5] | d_loss: 0.5576 | g_loss: 0.6333
# Epoch [    2/    5] | d_loss: 0.4662 | g_loss: 0.3828
# Epoch [    2/    5] | d_loss: 0.5657 | g_loss: 0.5544
# Epoch [    2/    5] | d_loss: 0.2765 | g_loss: 0.9046
# Epoch [    2/    5] | d_loss: 0.5242 | g_loss: 0.2448
# Epoch [    2/    5] | d_loss: 0.8308 | g_loss: 0.6345
# Epoch [    2/    5] | d_loss: 0.5227 | g_loss: 0.6764
# Epoch [    2/    5] | d_loss: 0.4812 | g_loss: 0.6891
# Epoch [    2/    5] | d_loss: 0.6673 | g_loss: 1.5855
# Epoch [    2/    5] | d_loss: 0.6792 | g_loss: 0.5598
# Epoch [    2/    5] | d_loss: 0.6375 | g_loss: 0.4631
# Epoch [    2/    5] | d_loss: 0.4378 | g_loss: 0.3460
# Epoch [    2/    5] | d_loss: 0.3954 | g_loss: 0.6077
# Epoch [    2/    5] | d_loss: 0.5658 | g_loss: 0.9273
# Epoch [    2/    5] | d_loss: 0.4147 | g_loss: 0.6238
# Epoch [    2/    5] | d_loss: 0.9608 | g_loss: 0.7713
# Epoch [    2/    5] | d_loss: 0.6101 | g_loss: 0.5991
# Epoch [    2/    5] | d_loss: 0.6215 | g_loss: 0.3853
# Epoch [    2/    5] | d_loss: 0.6818 | g_loss: 0.4620
# Epoch [    2/    5] | d_loss: 0.9080 | g_loss: 0.7627
# Epoch [    2/    5] | d_loss: 0.4361 | g_loss: 0.4183
# Epoch [    2/    5] | d_loss: 0.7568 | g_loss: 0.5762
# Epoch [    2/    5] | d_loss: 0.5862 | g_loss: 0.5886
# Epoch [    2/    5] | d_loss: 0.5529 | g_loss: 0.7342
# Epoch [    2/    5] | d_loss: 0.6365 | g_loss: 0.4011
# Epoch [    2/    5] | d_loss: 0.6830 | g_loss: 0.8513
# Epoch [    2/    5] | d_loss: 0.6745 | g_loss: 0.6307
# Epoch [    2/    5] | d_loss: 0.8215 | g_loss: 0.5120
# Epoch [    2/    5] | d_loss: 0.7494 | g_loss: 0.6296
# Epoch [    2/    5] | d_loss: 0.6889 | g_loss: 0.6299
# Epoch [    2/    5] | d_loss: 0.8820 | g_loss: 0.2720
# Epoch [    2/    5] | d_loss: 0.6032 | g_loss: 0.4448
# Epoch [    2/    5] | d_loss: 0.6419 | g_loss: 0.4849
# Epoch [    2/    5] | d_loss: 0.8435 | g_loss: 0.5508
# Epoch [    2/    5] | d_loss: 1.5456 | g_loss: 0.3032
# Epoch [    2/    5] | d_loss: 0.7047 | g_loss: 0.9948
# Epoch [    2/    5] | d_loss: 0.5691 | g_loss: 0.6547
# Epoch [    2/    5] | d_loss: 0.5983 | g_loss: 0.8717
# Epoch [    2/    5] | d_loss: 0.6859 | g_loss: 0.6881
# Epoch [    2/    5] | d_loss: 0.6593 | g_loss: 0.4809
# Epoch [    2/    5] | d_loss: 0.5143 | g_loss: 0.3270
# Epoch [    2/    5] | d_loss: 0.5767 | g_loss: 0.3275
# Epoch [    2/    5] | d_loss: 0.6497 | g_loss: 0.7033
# Epoch [    2/    5] | d_loss: 0.8143 | g_loss: 0.5528
# Epoch [    2/    5] | d_loss: 0.6358 | g_loss: 0.6041
# Epoch [    2/    5] | d_loss: 0.6579 | g_loss: 0.4494
# Epoch [    2/    5] | d_loss: 0.8318 | g_loss: 0.4740
# Epoch [    2/    5] | d_loss: 0.4906 | g_loss: 0.5666
# Epoch [    2/    5] | d_loss: 0.6596 | g_loss: 0.8951
# Epoch [    2/    5] | d_loss: 0.8951 | g_loss: 0.5206
# Epoch [    2/    5] | d_loss: 0.3955 | g_loss: 0.5223
# Epoch [    2/    5] | d_loss: 0.6139 | g_loss: 0.6932
# Epoch [    2/    5] | d_loss: 0.6678 | g_loss: 0.7391
# Epoch [    2/    5] | d_loss: 0.7040 | g_loss: 0.6845
# Epoch [    2/    5] | d_loss: 0.8320 | g_loss: 0.3085
# Epoch [    2/    5] | d_loss: 0.7582 | g_loss: 0.5239
# Epoch [    2/    5] | d_loss: 0.5182 | g_loss: 0.5121
# Epoch [    2/    5] | d_loss: 0.5299 | g_loss: 1.1711
# Epoch [    2/    5] | d_loss: 0.5133 | g_loss: 0.6621
# Epoch [    2/    5] | d_loss: 0.4691 | g_loss: 0.4648
# Epoch [    2/    5] | d_loss: 0.6218 | g_loss: 0.8046
# Epoch [    2/    5] | d_loss: 0.5276 | g_loss: 0.3821
# Epoch [    2/    5] | d_loss: 0.7029 | g_loss: 0.5562
# Epoch [    2/    5] | d_loss: 0.5718 | g_loss: 0.3286
# Epoch [    2/    5] | d_loss: 0.6748 | g_loss: 0.5055
# Epoch [    2/    5] | d_loss: 0.5386 | g_loss: 0.4072
# Epoch [    2/    5] | d_loss: 0.6229 | g_loss: 0.3956
# Epoch [    2/    5] | d_loss: 0.7945 | g_loss: 0.8565
# Epoch [    3/    5] | d_loss: 0.5390 | g_loss: 0.3574
# Epoch [    3/    5] | d_loss: 0.7570 | g_loss: 0.8774
# Epoch [    3/    5] | d_loss: 0.6238 | g_loss: 0.1589
# Epoch [    3/    5] | d_loss: 0.5927 | g_loss: 0.7024
# Epoch [    3/    5] | d_loss: 0.5669 | g_loss: 0.5034
# Epoch [    3/    5] | d_loss: 0.7711 | g_loss: 0.9161
# Epoch [    3/    5] | d_loss: 0.3656 | g_loss: 0.5727
# Epoch [    3/    5] | d_loss: 0.4981 | g_loss: 0.7822
# Epoch [    3/    5] | d_loss: 0.6901 | g_loss: 0.5163
# Epoch [    3/    5] | d_loss: 0.6460 | g_loss: 0.4526
# Epoch [    3/    5] | d_loss: 0.6500 | g_loss: 0.8785
# Epoch [    3/    5] | d_loss: 0.5271 | g_loss: 0.6533
# Epoch [    3/    5] | d_loss: 0.5682 | g_loss: 0.8103
# Epoch [    3/    5] | d_loss: 0.5381 | g_loss: 0.6221
# Epoch [    3/    5] | d_loss: 0.6548 | g_loss: 0.5276
# Epoch [    3/    5] | d_loss: 0.4772 | g_loss: 0.3826
# Epoch [    3/    5] | d_loss: 0.5224 | g_loss: 0.6553
# Epoch [    3/    5] | d_loss: 0.5616 | g_loss: 0.4019
# Epoch [    3/    5] | d_loss: 0.5466 | g_loss: 0.6084
# Epoch [    3/    5] | d_loss: 0.6863 | g_loss: 0.3830
# Epoch [    3/    5] | d_loss: 0.5368 | g_loss: 0.4123
# Epoch [    3/    5] | d_loss: 0.6763 | g_loss: 0.7072
# Epoch [    3/    5] | d_loss: 0.6637 | g_loss: 0.7815
# Epoch [    3/    5] | d_loss: 0.9856 | g_loss: 0.5166
# Epoch [    3/    5] | d_loss: 0.6119 | g_loss: 0.4380
# Epoch [    3/    5] | d_loss: 0.7167 | g_loss: 0.7694
# Epoch [    3/    5] | d_loss: 0.4819 | g_loss: 0.3327
# Epoch [    3/    5] | d_loss: 0.3852 | g_loss: 0.8254
# Epoch [    3/    5] | d_loss: 0.5969 | g_loss: 0.6616
# Epoch [    3/    5] | d_loss: 0.7766 | g_loss: 1.1225
# Epoch [    3/    5] | d_loss: 0.5861 | g_loss: 0.2004
# Epoch [    3/    5] | d_loss: 0.7288 | g_loss: 0.2829
# Epoch [    3/    5] | d_loss: 0.6163 | g_loss: 0.3878
# Epoch [    3/    5] | d_loss: 0.9401 | g_loss: 0.4734
# Epoch [    3/    5] | d_loss: 0.5131 | g_loss: 0.6912
# Epoch [    3/    5] | d_loss: 0.5596 | g_loss: 0.7529
# Epoch [    3/    5] | d_loss: 0.7152 | g_loss: 0.5814
# Epoch [    3/    5] | d_loss: 0.7043 | g_loss: 0.6817
# Epoch [    3/    5] | d_loss: 0.6149 | g_loss: 0.8105
# Epoch [    3/    5] | d_loss: 0.6350 | g_loss: 0.6841
# Epoch [    3/    5] | d_loss: 0.5325 | g_loss: 0.4957
# Epoch [    3/    5] | d_loss: 0.5415 | g_loss: 0.5805
# Epoch [    3/    5] | d_loss: 0.8550 | g_loss: 0.6709
# Epoch [    3/    5] | d_loss: 0.7456 | g_loss: 0.9487
# Epoch [    3/    5] | d_loss: 0.6010 | g_loss: 0.6737
# Epoch [    3/    5] | d_loss: 0.4925 | g_loss: 0.6655
# Epoch [    3/    5] | d_loss: 0.5509 | g_loss: 0.7095
# Epoch [    3/    5] | d_loss: 0.6166 | g_loss: 0.6382
# Epoch [    3/    5] | d_loss: 0.5466 | g_loss: 0.3132
# Epoch [    3/    5] | d_loss: 0.5990 | g_loss: 0.7025
# Epoch [    3/    5] | d_loss: 0.6330 | g_loss: 0.6084
# Epoch [    3/    5] | d_loss: 0.8371 | g_loss: 0.8934
# Epoch [    3/    5] | d_loss: 0.5364 | g_loss: 0.6114
# Epoch [    3/    5] | d_loss: 0.6409 | g_loss: 0.4783
# Epoch [    3/    5] | d_loss: 0.6694 | g_loss: 0.3113
# Epoch [    3/    5] | d_loss: 0.4924 | g_loss: 0.8593
# Epoch [    3/    5] | d_loss: 0.4212 | g_loss: 0.7588
# Epoch [    3/    5] | d_loss: 0.6388 | g_loss: 0.6545
# Epoch [    3/    5] | d_loss: 0.4600 | g_loss: 0.2718
# Epoch [    3/    5] | d_loss: 0.5874 | g_loss: 0.8329
# Epoch [    3/    5] | d_loss: 0.6671 | g_loss: 0.6878
# Epoch [    3/    5] | d_loss: 0.5563 | g_loss: 0.4972
# Epoch [    3/    5] | d_loss: 0.6171 | g_loss: 0.4207
# Epoch [    3/    5] | d_loss: 0.5827 | g_loss: 0.6297
# Epoch [    3/    5] | d_loss: 0.9833 | g_loss: 0.5018
# Epoch [    3/    5] | d_loss: 0.5935 | g_loss: 0.8131
# Epoch [    3/    5] | d_loss: 0.4870 | g_loss: 0.5545
# Epoch [    3/    5] | d_loss: 0.5812 | g_loss: 0.4240
# Epoch [    3/    5] | d_loss: 0.6547 | g_loss: 0.5162
# Epoch [    3/    5] | d_loss: 0.8649 | g_loss: 0.4700
# Epoch [    3/    5] | d_loss: 0.7253 | g_loss: 0.6265
# Epoch [    3/    5] | d_loss: 0.7225 | g_loss: 0.6833
# Epoch [    3/    5] | d_loss: 0.5682 | g_loss: 0.8198
# Epoch [    3/    5] | d_loss: 0.6491 | g_loss: 0.5363
# Epoch [    3/    5] | d_loss: 0.6075 | g_loss: 0.5498
# Epoch [    3/    5] | d_loss: 0.6221 | g_loss: 0.6763
# Epoch [    3/    5] | d_loss: 0.6615 | g_loss: 0.4604
# Epoch [    3/    5] | d_loss: 0.5816 | g_loss: 0.4199
# Epoch [    3/    5] | d_loss: 1.0622 | g_loss: 0.2791
# Epoch [    3/    5] | d_loss: 1.1758 | g_loss: 0.5243
# Epoch [    3/    5] | d_loss: 0.5150 | g_loss: 0.6431
# Epoch [    3/    5] | d_loss: 0.7045 | g_loss: 0.6096
# Epoch [    3/    5] | d_loss: 0.4858 | g_loss: 0.2994
# Epoch [    3/    5] | d_loss: 0.6107 | g_loss: 0.3488
# Epoch [    3/    5] | d_loss: 0.6873 | g_loss: 0.4946
# Epoch [    3/    5] | d_loss: 0.7180 | g_loss: 0.3113
# Epoch [    3/    5] | d_loss: 0.8421 | g_loss: 0.6420
# Epoch [    3/    5] | d_loss: 0.7068 | g_loss: 0.5551
# Epoch [    3/    5] | d_loss: 0.5754 | g_loss: 0.6663
# Epoch [    3/    5] | d_loss: 0.4498 | g_loss: 0.6148
# Epoch [    4/    5] | d_loss: 0.8376 | g_loss: 0.6035
# Epoch [    4/    5] | d_loss: 0.7058 | g_loss: 0.3452
# Epoch [    4/    5] | d_loss: 0.6369 | g_loss: 0.6433
# Epoch [    4/    5] | d_loss: 0.6781 | g_loss: 0.6982
# Epoch [    4/    5] | d_loss: 0.7388 | g_loss: 0.7567
# Epoch [    4/    5] | d_loss: 0.5471 | g_loss: 0.3994
# Epoch [    4/    5] | d_loss: 0.4632 | g_loss: 0.4829
# Epoch [    4/    5] | d_loss: 0.6081 | g_loss: 0.8845
# Epoch [    4/    5] | d_loss: 0.6808 | g_loss: 0.7069
# Epoch [    4/    5] | d_loss: 0.8564 | g_loss: 0.8492
# Epoch [    4/    5] | d_loss: 0.8048 | g_loss: 0.6001
# Epoch [    4/    5] | d_loss: 0.5777 | g_loss: 0.8141
# Epoch [    4/    5] | d_loss: 0.5138 | g_loss: 0.4468
# Epoch [    4/    5] | d_loss: 0.7150 | g_loss: 0.1311
# Epoch [    4/    5] | d_loss: 0.5530 | g_loss: 0.3672
# Epoch [    4/    5] | d_loss: 0.5961 | g_loss: 0.5514
# Epoch [    4/    5] | d_loss: 0.6651 | g_loss: 0.6311
# Epoch [    4/    5] | d_loss: 0.5959 | g_loss: 0.5288
# Epoch [    4/    5] | d_loss: 0.6816 | g_loss: 0.5611
# Epoch [    4/    5] | d_loss: 0.5958 | g_loss: 0.9483
# Epoch [    4/    5] | d_loss: 0.4769 | g_loss: 0.6033
# Epoch [    4/    5] | d_loss: 0.7016 | g_loss: 0.3328
# Epoch [    4/    5] | d_loss: 0.5952 | g_loss: 0.7678
# Epoch [    4/    5] | d_loss: 0.4608 | g_loss: 0.3785
# Epoch [    4/    5] | d_loss: 0.5730 | g_loss: 0.4526
# Epoch [    4/    5] | d_loss: 0.5844 | g_loss: 0.5680
# Epoch [    4/    5] | d_loss: 0.7721 | g_loss: 0.6509
# Epoch [    4/    5] | d_loss: 0.6156 | g_loss: 0.6524
# Epoch [    4/    5] | d_loss: 0.6004 | g_loss: 0.3543
# Epoch [    4/    5] | d_loss: 0.5415 | g_loss: 0.6698
# Epoch [    4/    5] | d_loss: 0.4641 | g_loss: 0.6660
# Epoch [    4/    5] | d_loss: 0.6271 | g_loss: 0.4345
# Epoch [    4/    5] | d_loss: 0.5787 | g_loss: 0.3431
# Epoch [    4/    5] | d_loss: 0.4422 | g_loss: 0.4400
# Epoch [    4/    5] | d_loss: 0.5531 | g_loss: 0.4864
# Epoch [    4/    5] | d_loss: 0.7000 | g_loss: 0.3375
# Epoch [    4/    5] | d_loss: 0.5301 | g_loss: 0.4758
# Epoch [    4/    5] | d_loss: 0.5701 | g_loss: 0.4561
# Epoch [    4/    5] | d_loss: 0.6428 | g_loss: 0.8874
# Epoch [    4/    5] | d_loss: 0.7984 | g_loss: 0.4910
# Epoch [    4/    5] | d_loss: 0.5893 | g_loss: 0.5792
# Epoch [    4/    5] | d_loss: 0.8316 | g_loss: 0.5111
# Epoch [    4/    5] | d_loss: 0.5579 | g_loss: 0.5016
# Epoch [    4/    5] | d_loss: 0.9063 | g_loss: 0.5304
# Epoch [    4/    5] | d_loss: 0.6237 | g_loss: 0.4902
# Epoch [    4/    5] | d_loss: 0.6230 | g_loss: 0.4787
# Epoch [    4/    5] | d_loss: 0.5363 | g_loss: 0.5164
# Epoch [    4/    5] | d_loss: 0.7183 | g_loss: 0.3793
# Epoch [    4/    5] | d_loss: 0.7442 | g_loss: 0.4454
# Epoch [    4/    5] | d_loss: 0.5751 | g_loss: 0.2209
# Epoch [    4/    5] | d_loss: 0.5488 | g_loss: 0.2649
# Epoch [    4/    5] | d_loss: 0.5961 | g_loss: 0.7849
# Epoch [    4/    5] | d_loss: 0.5786 | g_loss: 0.4759
# Epoch [    4/    5] | d_loss: 0.7505 | g_loss: 0.3639
# Epoch [    4/    5] | d_loss: 0.4783 | g_loss: 0.6538
# Epoch [    4/    5] | d_loss: 0.5779 | g_loss: 0.4706
# Epoch [    4/    5] | d_loss: 0.5386 | g_loss: 0.9489
# Epoch [    4/    5] | d_loss: 0.5307 | g_loss: 0.6465
# Epoch [    4/    5] | d_loss: 0.7203 | g_loss: 0.4619
# Epoch [    4/    5] | d_loss: 0.4873 | g_loss: 0.3106
# Epoch [    4/    5] | d_loss: 0.5207 | g_loss: 0.2838
# Epoch [    4/    5] | d_loss: 0.6656 | g_loss: 0.3611
# Epoch [    4/    5] | d_loss: 0.5213 | g_loss: 0.5636
# Epoch [    4/    5] | d_loss: 0.4405 | g_loss: 0.4979
# Epoch [    4/    5] | d_loss: 0.6324 | g_loss: 0.2568
# Epoch [    4/    5] | d_loss: 0.8123 | g_loss: 0.4317
# Epoch [    4/    5] | d_loss: 0.5777 | g_loss: 0.7592
# Epoch [    4/    5] | d_loss: 0.6455 | g_loss: 0.3573
# Epoch [    4/    5] | d_loss: 0.4638 | g_loss: 0.4957
# Epoch [    4/    5] | d_loss: 0.6683 | g_loss: 0.7515
# Epoch [    4/    5] | d_loss: 0.6641 | g_loss: 0.6831
# Epoch [    4/    5] | d_loss: 0.6248 | g_loss: 0.6573
# Epoch [    4/    5] | d_loss: 0.6504 | g_loss: 0.3811
# Epoch [    4/    5] | d_loss: 0.5269 | g_loss: 0.5617
# Epoch [    4/    5] | d_loss: 0.5673 | g_loss: 0.5457
# Epoch [    4/    5] | d_loss: 0.6299 | g_loss: 0.3676
# Epoch [    4/    5] | d_loss: 0.7954 | g_loss: 0.5572
# Epoch [    4/    5] | d_loss: 0.4937 | g_loss: 0.3507
# Epoch [    4/    5] | d_loss: 0.5243 | g_loss: 0.4497
# Epoch [    4/    5] | d_loss: 0.6302 | g_loss: 0.4951
# Epoch [    4/    5] | d_loss: 0.6192 | g_loss: 0.4465
# Epoch [    4/    5] | d_loss: 0.4691 | g_loss: 0.4644
# Epoch [    4/    5] | d_loss: 0.4956 | g_loss: 0.4510
# Epoch [    4/    5] | d_loss: 0.6960 | g_loss: 0.2992
# Epoch [    4/    5] | d_loss: 0.6098 | g_loss: 0.6507
# Epoch [    4/    5] | d_loss: 0.4611 | g_loss: 0.7171
# Epoch [    4/    5] | d_loss: 0.7566 | g_loss: 0.7633
# Epoch [    4/    5] | d_loss: 0.6068 | g_loss: 0.7086
# Epoch [    4/    5] | d_loss: 0.4135 | g_loss: 0.3944
# Epoch [    4/    5] | d_loss: 0.4795 | g_loss: 0.4252
# Epoch [    5/    5] | d_loss: 0.6807 | g_loss: 0.6094
# Epoch [    5/    5] | d_loss: 0.4457 | g_loss: 0.6290
# Epoch [    5/    5] | d_loss: 0.7058 | g_loss: 0.5299
# Epoch [    5/    5] | d_loss: 0.7591 | g_loss: 0.4726
# Epoch [    5/    5] | d_loss: 0.5887 | g_loss: 0.5036
# Epoch [    5/    5] | d_loss: 0.4126 | g_loss: 0.6210
# Epoch [    5/    5] | d_loss: 0.5046 | g_loss: 0.4888
# Epoch [    5/    5] | d_loss: 0.6476 | g_loss: 0.5159
# Epoch [    5/    5] | d_loss: 0.6093 | g_loss: 0.3785
# Epoch [    5/    5] | d_loss: 0.4946 | g_loss: 0.5998
# Epoch [    5/    5] | d_loss: 0.4274 | g_loss: 0.6436
# Epoch [    5/    5] | d_loss: 0.7522 | g_loss: 0.5873
# Epoch [    5/    5] | d_loss: 0.5998 | g_loss: 0.2436
# Epoch [    5/    5] | d_loss: 0.6355 | g_loss: 0.8654
# Epoch [    5/    5] | d_loss: 0.7028 | g_loss: 0.6327
# Epoch [    5/    5] | d_loss: 0.7083 | g_loss: 0.4519
# Epoch [    5/    5] | d_loss: 0.5721 | g_loss: 0.4576
# Epoch [    5/    5] | d_loss: 0.6508 | g_loss: 0.3256
# Epoch [    5/    5] | d_loss: 0.8127 | g_loss: 0.2806
# Epoch [    5/    5] | d_loss: 0.5791 | g_loss: 0.6525
# Epoch [    5/    5] | d_loss: 0.6034 | g_loss: 0.4741
# Epoch [    5/    5] | d_loss: 0.6511 | g_loss: 0.3296
# Epoch [    5/    5] | d_loss: 0.4656 | g_loss: 0.3840
# Epoch [    5/    5] | d_loss: 0.4852 | g_loss: 0.5295
# Epoch [    5/    5] | d_loss: 0.6914 | g_loss: 0.2936
# Epoch [    5/    5] | d_loss: 0.5475 | g_loss: 0.8994
# Epoch [    5/    5] | d_loss: 0.6027 | g_loss: 0.4112
# Epoch [    5/    5] | d_loss: 0.7598 | g_loss: 0.4140
# Epoch [    5/    5] | d_loss: 0.6577 | g_loss: 0.8125
# Epoch [    5/    5] | d_loss: 0.6092 | g_loss: 0.4364
# Epoch [    5/    5] | d_loss: 0.3848 | g_loss: 0.6015
# Epoch [    5/    5] | d_loss: 0.5259 | g_loss: 0.5857
# Epoch [    5/    5] | d_loss: 0.6862 | g_loss: 1.1175
# Epoch [    5/    5] | d_loss: 0.6170 | g_loss: 0.4070
# Epoch [    5/    5] | d_loss: 0.6438 | g_loss: 0.4713
# Epoch [    5/    5] | d_loss: 0.5691 | g_loss: 0.4581
# Epoch [    5/    5] | d_loss: 0.5797 | g_loss: 0.3025
# Epoch [    5/    5] | d_loss: 0.6889 | g_loss: 0.6354
# Epoch [    5/    5] | d_loss: 0.6806 | g_loss: 0.5293
# Epoch [    5/    5] | d_loss: 0.7894 | g_loss: 0.7153
# Epoch [    5/    5] | d_loss: 0.5377 | g_loss: 0.6253
# Epoch [    5/    5] | d_loss: 0.6899 | g_loss: 0.5963
# Epoch [    5/    5] | d_loss: 0.4848 | g_loss: 0.5685
# Epoch [    5/    5] | d_loss: 0.5648 | g_loss: 0.6573
# Epoch [    5/    5] | d_loss: 0.8222 | g_loss: 0.5461
# Epoch [    5/    5] | d_loss: 0.6005 | g_loss: 0.3746
# Epoch [    5/    5] | d_loss: 0.4766 | g_loss: 0.4989
# Epoch [    5/    5] | d_loss: 0.6335 | g_loss: 0.6624
# Epoch [    5/    5] | d_loss: 0.5646 | g_loss: 0.8219
# Epoch [    5/    5] | d_loss: 0.4483 | g_loss: 0.2610
# Epoch [    5/    5] | d_loss: 0.5907 | g_loss: 0.5320
# Epoch [    5/    5] | d_loss: 0.5743 | g_loss: 0.9131
# Epoch [    5/    5] | d_loss: 0.6171 | g_loss: 0.3115
# Epoch [    5/    5] | d_loss: 0.6278 | g_loss: 0.4142
# Epoch [    5/    5] | d_loss: 0.7139 | g_loss: 0.5203
# Epoch [    5/    5] | d_loss: 0.5160 | g_loss: 0.3498
# Epoch [    5/    5] | d_loss: 0.5704 | g_loss: 0.3307
# Epoch [    5/    5] | d_loss: 0.6400 | g_loss: 0.9045
# Epoch [    5/    5] | d_loss: 0.3848 | g_loss: 0.4692
# Epoch [    5/    5] | d_loss: 0.6135 | g_loss: 0.4859
# Epoch [    5/    5] | d_loss: 0.3806 | g_loss: 0.4454
# Epoch [    5/    5] | d_loss: 0.5179 | g_loss: 0.4356
# Epoch [    5/    5] | d_loss: 0.4746 | g_loss: 0.4184
# Epoch [    5/    5] | d_loss: 0.6091 | g_loss: 0.2553
# Epoch [    5/    5] | d_loss: 0.5214 | g_loss: 0.3150
# Epoch [    5/    5] | d_loss: 0.6785 | g_loss: 0.4431
# Epoch [    5/    5] | d_loss: 0.6337 | g_loss: 0.6560
# Epoch [    5/    5] | d_loss: 0.6535 | g_loss: 0.3056
# Epoch [    5/    5] | d_loss: 0.6739 | g_loss: 0.7805
# Epoch [    5/    5] | d_loss: 0.5011 | g_loss: 0.7001
# Epoch [    5/    5] | d_loss: 0.7034 | g_loss: 0.6328
# Epoch [    5/    5] | d_loss: 0.4704 | g_loss: 0.8405
# Epoch [    5/    5] | d_loss: 0.6530 | g_loss: 0.4429
# Epoch [    5/    5] | d_loss: 0.6518 | g_loss: 0.3185
# Epoch [    5/    5] | d_loss: 0.6483 | g_loss: 0.6797
# Epoch [    5/    5] | d_loss: 0.6508 | g_loss: 0.4212
# Epoch [    5/    5] | d_loss: 0.5805 | g_loss: 0.6549
# Epoch [    5/    5] | d_loss: 0.6374 | g_loss: 0.4074
# Epoch [    5/    5] | d_loss: 0.6960 | g_loss: 0.4208
# Epoch [    5/    5] | d_loss: 0.6709 | g_loss: 0.3838
# Epoch [    5/    5] | d_loss: 0.7786 | g_loss: 0.6464
# Epoch [    5/    5] | d_loss: 0.5961 | g_loss: 0.5187
# Epoch [    5/    5] | d_loss: 0.8215 | g_loss: 0.6518
# Epoch [    5/    5] | d_loss: 0.5326 | g_loss: 0.3720
# Epoch [    5/    5] | d_loss: 0.5215 | g_loss: 0.4457
# Epoch [    5/    5] | d_loss: 0.6388 | g_loss: 0.5041
# Epoch [    5/    5] | d_loss: 0.6114 | g_loss: 0.5407
# Epoch [    5/    5] | d_loss: 0.9350 | g_loss: 1.2849
# Epoch [    5/    5] | d_loss: 0.9570 | g_loss: 0.3687
# Epoch [    5/    5] | d_loss: 0.5061 | g_loss: 0.6227

# %% [markdown]
# ## Training loss
#
# Plot the training losses for the generator and discriminator, recorded after each epoch.

# %%
fig, ax = plt.subplots()
losses = np.array(losses)
plt.plot(losses.T[0], label='Discriminator', alpha=0.5)
plt.plot(losses.T[1], label='Generator', alpha=0.5)
plt.title("Training Losses")
plt.legend()
#plt.rcParams['figure.figsize'] = [10, 5]

# %% [markdown]
# ## Generator samples from training
#
# View samples of images from the generator, and answer a question about the strengths and weaknesses of your trained models.

# %%
# helper function for viewing a list of passed in sample images
def view_samples(epoch, samples):
    fig, axes = plt.subplots(figsize=(16,4), nrows=2, ncols=8, sharey=True, sharex=True)
    for ax, img in zip(axes.flatten(), samples[epoch]):
        img = img.detach().cpu().numpy()
        img = np.transpose(img, (1, 2, 0))
        img = ((img + 1)*255 / (2)).astype(np.uint8)
        ax.xaxis.set_visible(False)
        ax.yaxis.set_visible(False)
        im = ax.imshow(img.reshape((32,32,3)))

# %%
# Load samples from generator, taken while training
with open('train_samples.pkl', 'rb') as f:
    samples = pkl.load(f)

# %%
_ = view_samples(-1, samples)

# %% [markdown]
# ### Question: What do you notice about your generated samples and how might you improve this model?
# When you answer this question, consider the following factors:
# * The dataset is biased; it is made of "celebrity" faces that are mostly white
# * Model size; larger models have the opportunity to learn more features in a data feature space
# * Optimization strategy; optimizers and number of epochs affect your final result

# %% [markdown]
# **Answer:**
#
# I noticed that the model tries to create a fake human face using at least 2 similar pictures.
#
# In order to improve this model, I did the tests below:
#
# Using the dropout=0.5, batch_size=64, d_conv_dim=128, g_conv_dim=128 and epoch=2, the generated samples are as following:
# ![art text](face_generator_tests/batch_64_conv_dim_128_dropout_50%.PNG)
# As you can notice, they are blurred images.<br/>
#
# Increasing the epochs to 5, I could notice less noisy samples being generated.
# ![art text](face_generator_tests/batch_64_conv_dim_128_dropout_50%_epoch5.PNG)
# <br/>
#
# I changed the batch_size to 20, dropout to 0.2, few generated samples are quite good, but some images are still strange.
# ![art text](face_generator_tests/batch_20_conv_dim_128_dropout_20%_epoch5.PNG)
# <br/>
#
# I tried to increase the batch_size to 128, but I could not see significant improvement and the model needs more epochs to train and give the same results as batch_size=20.<br/>
#
# I believe that the model can perform better, in point of view of fake generated images, if the dataset were cleaned and remove people wearing sunglasses, heavy makeup, caps, etc, because it created strange fake faces. I also would use faces that are looking to same direction. In my opinion, the model might produce more convincing fake faces compared to current output.
# In point of view of model, perhaps it is possible to improve it using Residual Blocks.

# %% [markdown]
# ### Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook. Save the notebook file as "dlnd_face_generation.ipynb" and save it as a HTML file under "File" -> "Download as". Include the "problem_unittests.py" files in your submission.
